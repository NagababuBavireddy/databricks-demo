# %%
# Configuration
source_dir = "/Volumes/demo-external-catalog/default/incremental_load/orders_data/source/"
archive_dir = "/Volumes/demo-external-catalog/default/incremental_load/orders_data/archive/"
stage_table = "`demo-external-catalog`.default.orders_stage"
error_table = "`demo-external-catalog`.default.orders_errors"

print(f"Processing orders data from: {source_dir}")
print(f"Staging table: {stage_table}")
